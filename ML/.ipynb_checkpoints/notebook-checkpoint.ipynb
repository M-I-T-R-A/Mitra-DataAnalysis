# %%
## Importing necessary libraries

import pandas as pd
import numpy as np
import random
import math
from math import floor
from random import sample
from tqdm import tqdm
import requests
import json

# %%
## Fetching Customer's data from database
customer_id = input("Enter Customer id")
data = requests.get('http://20.198.81.29:5000/admin/customer/' + customer_id)

data = data.json()
data
# Out:
# Enter Customer id 1
# {'customer': {'id': 1,
#   'name': 'Ajinkya Taranekar',
#   'gender': 'MALE',
#   'phoneNumber': '8518076044',
#   'annualIncome': 100000.0,
#   'aadhar': '871836501211',
#   'pan': 'BSMPT6753Q',
#   'electricityBill': 1996.0,
#   'residenceAddress': {'firstLine': '66, Scheme No 114',
#    'secondLine': 'Indore',
#    'city': 'Indore',
#    'state': 'Madhya Pradesh',
#    'pincode': None,
#    'longitude': 75.8981,
#    'latitude': 22.7681},
#   'aadharCardFrontImageUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FAadhar%2Ffdc82b09-000b-4ce5-bf8c-f001db88b1841506725469182819881.jpg?alt=media&token=80798974-35a0-4aae-94e8-600b4015720e',
#   'aadharCardBackImageUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FAadhar%2F58e59726-faad-487a-8b64-240eb24979ab1749815431958091906.jpg?alt=media&token=5ff7f7c5-e9f1-4f9a-b6e7-764c1e008ba6',
#   'panCardImageUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FPAN%2Fa35b2b4b-bb1b-451c-abae-0cc588283c402550725679873019440.jpg?alt=media&token=4895937a-a496-4b3e-b224-509db9d9daaf',
#   'electricityBillImageUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FElectricityBill%2FHome%2Fc0b29d30-29b5-44af-b415-8d8b7964e82a3582077312473763993.jpg?alt=media&token=9dbb6273-7da7-42a5-8155-f5b3af6f4108',
#   'cibilScore': None,
#   'haveCurrentLoan': False,
#   'checkNumber': None,
#   'status': 7,
#   'verified': None},
#  'allLoans': [{'id': 8,
#    'demandedAmount': 100000.0,
#    'approval': 'WAITING',
#    'approvedInstantLoan': None},
#   {'id': 11,
#    'demandedAmount': 10000.0,
#    'approval': 'REJECTED',
#    'approvedInstantLoan': None},
#   {'id': 12,
#    'demandedAmount': 100000.0,
#    'approval': 'REJECTED',
#    'approvedInstantLoan': None},
#   {'id': 13,
#    'demandedAmount': 1.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 14,
#     'approvedAmount': None,
#     'rateOfInterest': None,
#     'timeFactor': None,
#     'startDate': None,
#     'endDate': None}},
#   {'id': 15,
#    'demandedAmount': 100000.0,
#    'approval': 'REJECTED',
#    'approvedInstantLoan': None},
#   {'id': 18,
#    'demandedAmount': 0.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 19,
#     'approvedAmount': None,
#     'rateOfInterest': None,
#     'timeFactor': None,
#     'startDate': None,
#     'endDate': None}},
#   {'id': 20,
#    'demandedAmount': 110.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 23,
#     'approvedAmount': 0.0,
#     'rateOfInterest': 0.0,
#     'timeFactor': 0.0,
#     'startDate': '2000-12-10',
#     'endDate': '2000-12-10'}},
#   {'id': 21,
#    'demandedAmount': 110.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 22,
#     'approvedAmount': 0.0,
#     'rateOfInterest': 0.0,
#     'timeFactor': 0.0,
#     'startDate': '2000-12-10',
#     'endDate': '2000-12-10'}},
#   {'id': 24,
#    'demandedAmount': 2300.0,
#    'approval': 'WAITING',
#    'approvedInstantLoan': None},
#   {'id': 25,
#    'demandedAmount': 2300.0,
#    'approval': 'REJECTED',
#    'approvedInstantLoan': None},
#   {'id': 26,
#    'demandedAmount': 4300.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 27,
#     'approvedAmount': 4000.0,
#     'rateOfInterest': 10.0,
#     'timeFactor': 0.5,
#     'startDate': '2021-12-12',
#     'endDate': '2020-12-12'}},
#   {'id': 28,
#    'demandedAmount': 43000.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 29,
#     'approvedAmount': None,
#     'rateOfInterest': None,
#     'timeFactor': None,
#     'startDate': None,
#     'endDate': None}},
#   {'id': 30,
#    'demandedAmount': 5000.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 31,
#     'approvedAmount': None,
#     'rateOfInterest': None,
#     'timeFactor': None,
#     'startDate': None,
#     'endDate': None}},
#   {'id': 32,
#    'demandedAmount': 6000.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 33,
#     'approvedAmount': 4000.0,
#     'rateOfInterest': 10.0,
#     'timeFactor': 0.5,
#     'startDate': '2021-12-12',
#     'endDate': '2020-12-12'}},
#   {'id': 34,
#    'demandedAmount': 7000.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 35,
#     'approvedAmount': 123.0,
#     'rateOfInterest': 123.0,
#     'timeFactor': 123.0,
#     'startDate': '2021-01-13',
#     'endDate': '2021-01-22'}},
#   {'id': 36,
#    'demandedAmount': 8000.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 37,
#     'approvedAmount': 432.0,
#     'rateOfInterest': 432.0,
#     'timeFactor': 432.0,
#     'startDate': '2021-01-18',
#     'endDate': '2021-01-28'}},
#   {'id': 38,
#    'demandedAmount': 150.0,
#    'approval': 'REJECTED',
#    'approvedInstantLoan': None},
#   {'id': 39,
#    'demandedAmount': 250.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 40,
#     'approvedAmount': 25000.0,
#     'rateOfInterest': 120.0,
#     'timeFactor': 0.01,
#     'startDate': '2021-01-13',
#     'endDate': '2021-01-28'}},
#   {'id': 41,
#    'demandedAmount': 2500.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 42,
#     'approvedAmount': 2500.0,
#     'rateOfInterest': 12.0,
#     'timeFactor': 12.0,
#     'startDate': '2021-01-12',
#     'endDate': '2021-01-28'}},
#   {'id': 43,
#    'demandedAmount': 10000.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 44,
#     'approvedAmount': 10000000.0,
#     'rateOfInterest': 69420.0,
#     'timeFactor': 0.69,
#     'startDate': '2010-10-01',
#     'endDate': '2022-01-05'}},
#   {'id': 47,
#    'demandedAmount': 100000.0,
#    'approval': 'APPROVED',
#    'approvedInstantLoan': {'id': 48,
#     'approvedAmount': 1201.0,
#     'rateOfInterest': 1.0,
#     'timeFactor': 0.5,
#     'startDate': '2000-10-10',
#     'endDate': '2000-10-10'}},
#   {'id': 51,
#    'demandedAmount': 50000.0,
#    'approval': 'WAITING',
#    'approvedInstantLoan': None}],
#  'instantLoanSurrogates': {'id': 1,
#   'locationCategory': None,
#   'competition': None,
#   'rating': None,
#   'assetsList': [],
#   'taxReturns': [{'date': '2021-02-12',
#     'tax': 0.0,
#     'itrDocumentUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FincomeTaxStatements%2Finvoice_8989674534_February%2012%2C%202021.pdf?alt=media&token=cbc58e65-9796-4f15-9f4f-30c6fff1974d'}],
#   'bills': [{'id': 5,
#     'supplierName': None,
#     'supplierMobile': None,
#     'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FPassBook%2Fd7330ed5-c433-4569-b83d-0d985c7c2b267320482589698754135.jpg?alt=media&token=ecf01eb7-ad11-4900-8889-c6513e56ed31',
#     'purchasedItemStock': None}],
#   'guarantor': {'id': 2,
#    'name': 'Malay Saxena ',
#    'gender': 'MALE',
#    'phoneNumber': None,
#    'annualIncome': 150.0,
#    'aadhar': '871836501211',
#    'pan': None,
#    'electricityBill': 4500.0,
#    'residenceAddress': {'firstLine': 'Chandan Nagar Garden, M R 9 Road',
#     'secondLine': 'Ward 35, Indore',
#     'city': 'Indore',
#     'state': 'Madhya Pradesh',
#     'pincode': None,
#     'longitude': 75.8947,
#     'latitude': 22.7422},
#    'aadharCardFrontImageUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FGurrantor%2FAadhar%2F7822a414-40e5-452d-8a02-626d4833c1a74257702354150695196.jpg?alt=media&token=67360572-6807-4664-b827-c41a679fd601',
#    'aadharCardBackImageUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FGurrantor%2FAadhar%2Fbcc0b3fb-ac76-4027-864e-9b1a516c65766580348693131109770.jpg?alt=media&token=cacaf280-b4f1-4503-b9bb-146ea53051f3',
#    'panCardImageUrl': None,
#    'electricityBillImageUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FGurrantor%2FElectricityBill%2Fb3b7931e-06b8-4a6f-828c-a93d86b7521d2880028377434835733.jpg?alt=media&token=2a131c5f-bae3-4644-b585-6bcfc4815d50',
#    'cibilScore': None,
#    'worthy': None,
#    'verified': None},
#   'creditAmountOfShopCustomers': []},
#  'allBankAccounts': [{'id': 4,
#    'ifsc': None,
#    'accountNumber': None,
#    'bankStatementImageUrls': ['https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FBankStatement%2Fallahbad_bank.pdf?alt=media&token=ffcb3d24-cf17-4944-a690-da6fc514ce7e'],
#    'currentValue': None}],
#  'shop': {'id': 3,
#   'shopName': 'Aditya Grocery',
#   'shopAddress': {'firstLine': 'Scheme No 78 Taxi Stand, Brilliant Convention Centre Road, Scheme No 78 Vijay Nagar',
#    'secondLine': 'Ward 8, Indore',
#    'city': 'Indore',
#    'state': 'Madhya Pradesh',
#    'pincode': None,
#    'longitude': 75.8912,
#    'latitude': 22.7606},
#   'phoneNumber': '9340887479',
#   'area': 500.0,
#   'type': 'GROCERY',
#   'rating': None,
#   'electricityAmount': 1996.0,
#   'electricityBillImageUrl': 'https://firebasestorage.googleapis.com/v0/b/mitra-aad4b.appspot.com/o/IkQosGbzQrXVc8fQzorhvQZjIBX2%2FElectricityBill%2FStore%2F76ec7da0-9c14-4fa1-a1f8-8f0353ac330a1756230028350483608.jpg?alt=media&token=32d0139b-dac9-4371-af21-d739104b7c63',
#   'ownership': 'PURCHASED',
#   'shopRelatedDocs': [],
#   'wareHouse': {'numberOfWareHouses': 1,
#    'areaOfWareHouses': [500.0],
#    'itemsSet': [{'name': 'Pure Cow Ghee',
#      'pricePerUnit': 443.0,
#      'unit': '1 L Pouch',
#      'quantity': 21,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Dranex Drain Cleaner',
#      'pricePerUnit': 130.0,
#      'unit': '50 g (Pack of 6)',
#      'quantity': 18,
#      'category': 'cleaning-household'},
#     {'name': 'Moong Dal',
#      'pricePerUnit': 119.0,
#      'unit': '1 kg Pouch',
#      'quantity': 22,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Food Safe Wipes',
#      'pricePerUnit': 126.0,
#      'unit': '30 pcs',
#      'quantity': 24,
#      'category': 'cleaning-household'},
#     {'name': 'Organic - Sugar',
#      'pricePerUnit': 78.0,
#      'unit': '1 kg',
#      'quantity': 13,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Baby Bib - Boy, 0m+',
#      'pricePerUnit': 699.0,
#      'unit': '2 pcs',
#      'quantity': 10,
#      'category': 'baby-care'},
#     {'name': 'Mentos - Fruit',
#      'pricePerUnit': 50.0,
#      'unit': '37 g',
#      'quantity': 17,
#      'category': 'gourmet-world-food'},
#     {'name': 'Instant Coffee',
#      'pricePerUnit': 289.0,
#      'unit': '200 g Pouch',
#      'quantity': 20,
#      'category': 'beverages'},
#     {'name': 'Feta Cheese',
#      'pricePerUnit': 320.0,
#      'unit': '200 g',
#      'quantity': 23,
#      'category': 'gourmet-world-food'},
#     {'name': 'Car Brush New',
#      'pricePerUnit': 119.0,
#      'unit': '1 pc 13 X 3 cm',
#      'quantity': 9,
#      'category': 'cleaning-household'},
#     {'name': 'Cloth Clip',
#      'pricePerUnit': 170.0,
#      'unit': '12 pcs',
#      'quantity': 14,
#      'category': 'cleaning-household'},
#     {'name': 'Cheese Bagel',
#      'pricePerUnit': 79.0,
#      'unit': '250 g',
#      'quantity': 13,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Sunflower Seeds',
#      'pricePerUnit': 53.0,
#      'unit': '100 g',
#      'quantity': 5,
#      'category': 'gourmet-world-food'},
#     {'name': 'Oats',
#      'pricePerUnit': 195.0,
#      'unit': '1.5 kg Pouch',
#      'quantity': 7,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Power Cleaner',
#      'pricePerUnit': 75.0,
#      'unit': '400 ml',
#      'quantity': 2,
#      'category': 'cleaning-household'},
#     {'name': 'Lip Balm',
#      'pricePerUnit': 34.0,
#      'unit': '10 g',
#      'quantity': 20,
#      'category': 'beauty-hygiene'},
#     {'name': 'WD 40',
#      'pricePerUnit': 99.0,
#      'unit': '63.8 g',
#      'quantity': 19,
#      'category': 'cleaning-household'},
#     {'name': 'Kitchen Sink Brush',
#      'pricePerUnit': 119.0,
#      'unit': '1 pc',
#      'quantity': 24,
#      'category': 'cleaning-household'},
#     {'name': 'Raw Mango',
#      'pricePerUnit': 57.0,
#      'unit': '500 g',
#      'quantity': 16,
#      'category': 'fruits-vegetables'},
#     {'name': 'Toor/Arhar Dal',
#      'pricePerUnit': 580.0,
#      'unit': '5 kg Pouch',
#      'quantity': 21,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Baby Soap - Blossoms',
#      'pricePerUnit': 51.0,
#      'unit': '75 g',
#      'quantity': 24,
#      'category': 'baby-care'},
#     {'name': 'Salt - Crystal',
#      'pricePerUnit': 14.0,
#      'unit': '1 kg Pouch',
#      'quantity': 10,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Tea',
#      'pricePerUnit': 116.0,
#      'unit': '250 g Carton',
#      'quantity': 7,
#      'category': 'beverages'},
#     {'name': 'Tea',
#      'pricePerUnit': 462.0,
#      'unit': '2x500 g Multipack',
#      'quantity': 2,
#      'category': 'beverages'},
#     {'name': 'Frozen - Green Peas',
#      'pricePerUnit': 54.0,
#      'unit': '200 g Pouch',
#      'quantity': 24,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Cucumber',
#      'pricePerUnit': 8.0,
#      'unit': '500 g',
#      'quantity': 17,
#      'category': 'fruits-vegetables'},
#     {'name': 'Classic Coffee',
#      'pricePerUnit': 490.0,
#      'unit': '200 g Stabilo',
#      'quantity': 12,
#      'category': 'beverages'},
#     {'name': 'Powder - Wheat Grass',
#      'pricePerUnit': 288.0,
#      'unit': '100 g',
#      'quantity': 19,
#      'category': 'gourmet-world-food'},
#     {'name': 'Apple Cider Vinegar',
#      'pricePerUnit': 263.0,
#      'unit': '500 ml',
#      'quantity': 17,
#      'category': 'gourmet-world-food'},
#     {'name': 'Instant Coffee',
#      'pricePerUnit': 306.0,
#      'unit': '2x100 g Multipack',
#      'quantity': 16,
#      'category': 'beverages'},
#     {'name': 'Oats',
#      'pricePerUnit': 199.0,
#      'unit': '1 kg (Get 400g Free)',
#      'quantity': 20,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Nail Polish S Series',
#      'pricePerUnit': 141.0,
#      'unit': '3x5 ml Multipack',
#      'quantity': 11,
#      'category': 'beauty-hygiene'},
#     {'name': 'Pure Cow Ghee',
#      'pricePerUnit': 1390.0,
#      'unit': '2x1 L (Multipack)',
#      'quantity': 8,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Pomegranate - Small',
#      'pricePerUnit': 129.0,
#      'unit': '1 kg',
#      'quantity': 3,
#      'category': 'fruits-vegetables'},
#     {'name': 'French - Fries',
#      'pricePerUnit': 95.0,
#      'unit': '420 g',
#      'quantity': 18,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Potato Crisps - BBQ',
#      'pricePerUnit': 260.0,
#      'unit': '158 g',
#      'quantity': 3,
#      'category': 'gourmet-world-food'},
#     {'name': 'Sprouts - Mixed Gram',
#      'pricePerUnit': 26.0,
#      'unit': '200 g',
#      'quantity': 22,
#      'category': 'fruits-vegetables'},
#     {'name': 'Baby Soap',
#      'pricePerUnit': 84.0,
#      'unit': '150 g',
#      'quantity': 25,
#      'category': 'baby-care'},
#     {'name': 'Lip Moisturizer',
#      'pricePerUnit': 184.0,
#      'unit': '4 g',
#      'quantity': 15,
#      'category': 'beauty-hygiene'},
#     {'name': 'Nachos - Spinach',
#      'pricePerUnit': 42.0,
#      'unit': '70 g',
#      'quantity': 22,
#      'category': 'gourmet-world-food'},
#     {'name': 'Avocado',
#      'pricePerUnit': 123.0,
#      'unit': '500 g',
#      'quantity': 15,
#      'category': 'fruits-vegetables'},
#     {'name': 'Capsicum - Red',
#      'pricePerUnit': 70.0,
#      'unit': '500 g',
#      'quantity': 11,
#      'category': 'fruits-vegetables'},
#     {'name': 'Ultra Power+ Fan',
#      'pricePerUnit': 368.0,
#      'unit': '45 ml (6 Refills Pack)',
#      'quantity': 3,
#      'category': 'cleaning-household'},
#     {'name': 'Original Cinnamon',
#      'pricePerUnit': 115.0,
#      'unit': '50 g',
#      'quantity': 18,
#      'category': 'gourmet-world-food'},
#     {'name': 'Cucumber - Mangalore',
#      'pricePerUnit': 21.0,
#      'unit': '1 kg',
#      'quantity': 8,
#      'category': 'fruits-vegetables'},
#     {'name': 'Silk Finish Lipstick',
#      'pricePerUnit': 121.0,
#      'unit': '3.6 g Just Garnet',
#      'quantity': 9,
#      'category': 'beauty-hygiene'},
#     {'name': '100% Whole Wheat',
#      'pricePerUnit': 44.0,
#      'unit': '400 g',
#      'quantity': 10,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Pacifier',
#      'pricePerUnit': 149.0,
#      'unit': '1 pc (Get Free Sterilisation Case)',
#      'quantity': 8,
#      'category': 'baby-care'},
#     {'name': 'Bread - Garlic',
#      'pricePerUnit': 64.0,
#      'unit': '200 g',
#      'quantity': 6,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Nail Polish Remover',
#      'pricePerUnit': 81.0,
#      'unit': '55 ml',
#      'quantity': 20,
#      'category': 'beauty-hygiene'},
#     {'name': 'Healthy Ragi Chips',
#      'pricePerUnit': 89.0,
#      'unit': '100 g',
#      'quantity': 25,
#      'category': 'gourmet-world-food'},
#     {'name': 'Mascarpone',
#      'pricePerUnit': 200.0,
#      'unit': '150 g',
#      'quantity': 12,
#      'category': 'gourmet-world-food'},
#     {'name': 'Atta - Chakki Fresh',
#      'pricePerUnit': 379.0,
#      'unit': '10 kg Pouch',
#      'quantity': 10,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Dranex Drain Cleaner',
#      'pricePerUnit': 22.0,
#      'unit': '50 g Pouch',
#      'quantity': 12,
#      'category': 'cleaning-household'},
#     {'name': 'Coconut - Medium',
#      'pricePerUnit': 30.0,
#      'unit': '1 pc',
#      'quantity': 3,
#      'category': 'fruits-vegetables'},
#     {'name': 'Black Pepper - Whole',
#      'pricePerUnit': 699.0,
#      'unit': '100 g',
#      'quantity': 24,
#      'category': 'gourmet-world-food'},
#     {'name': 'Baby Wipes',
#      'pricePerUnit': 59.0,
#      'unit': '20 Pulls',
#      'quantity': 3,
#      'category': 'baby-care'},
#     {'name': "Press 'N Seal",
#      'pricePerUnit': 500.0,
#      'unit': '70 pcs Box',
#      'quantity': 23,
#      'category': 'cleaning-household'},
#     {'name': 'Kajal',
#      'pricePerUnit': 118.0,
#      'unit': '2.6 g',
#      'quantity': 15,
#      'category': 'beauty-hygiene'},
#     {'name': 'Sugarcane - Diced',
#      'pricePerUnit': 15.0,
#      'unit': '200 g',
#      'quantity': 6,
#      'category': 'fruits-vegetables'},
#     {'name': 'Glass Cleaner Spray',
#      'pricePerUnit': 130.0,
#      'unit': '500 ml',
#      'quantity': 25,
#      'category': 'cleaning-household'},
#     {'name': 'Danish - Blueberry',
#      'pricePerUnit': 119.0,
#      'unit': '100 g Pack of 2',
#      'quantity': 21,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Body Ice Cream',
#      'pricePerUnit': 225.0,
#      'unit': '165 g',
#      'quantity': 12,
#      'category': 'beauty-hygiene'},
#     {'name': 'Dodha',
#      'pricePerUnit': 79.0,
#      'unit': '50 g',
#      'quantity': 11,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Coffee - Classic',
#      'pricePerUnit': 280.0,
#      'unit': '2x50 g Multipack',
#      'quantity': 9,
#      'category': 'beverages'},
#     {'name': 'Sugar',
#      'pricePerUnit': 38.0,
#      'unit': '1 kg',
#      'quantity': 2,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Pudding - Assorted',
#      'pricePerUnit': 50.0,
#      'unit': '170 g (Pack of 2)',
#      'quantity': 14,
#      'category': 'gourmet-world-food'},
#     {'name': 'Besan Laddoo',
#      'pricePerUnit': 100.0,
#      'unit': '200 g',
#      'quantity': 14,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Chicken Seekh Kebab',
#      'pricePerUnit': 201.0,
#      'unit': '500 g',
#      'quantity': 18,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Moonfils Choco Cream',
#      'pricePerUnit': 14.0,
#      'unit': '45 g Pouch',
#      'quantity': 13,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Nail Polish Remover',
#      'pricePerUnit': 179.0,
#      'unit': '3x35 ml Multipack',
#      'quantity': 24,
#      'category': 'beauty-hygiene'},
#     {'name': 'Steel Cut Oats',
#      'pricePerUnit': 300.0,
#      'unit': '1 kg',
#      'quantity': 11,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Ultra Power+ Fan',
#      'pricePerUnit': 126.0,
#      'unit': '45 ml (Twin Pack)',
#      'quantity': 17,
#      'category': 'cleaning-household'},
#     {'name': 'Baby Wet Wipes',
#      'pricePerUnit': 245.0,
#      'unit': '30 pcs Pack of 5',
#      'quantity': 0,
#      'category': 'baby-care'},
#     {'name': 'Moonfils Orange',
#      'pricePerUnit': 15.0,
#      'unit': '45 g Pouch',
#      'quantity': 5,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Dust Tea',
#      'pricePerUnit': 156.0,
#      'unit': '250 g',
#      'quantity': 0,
#      'category': 'beverages'},
#     {'name': 'Red Velvet Cake',
#      'pricePerUnit': 284.0,
#      'unit': '200 g',
#      'quantity': 0,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Seeds - Chia',
#      'pricePerUnit': 175.0,
#      'unit': '250 g',
#      'quantity': 14,
#      'category': 'gourmet-world-food'},
#     {'name': 'Tea - Golden Leaf',
#      'pricePerUnit': 180.0,
#      'unit': '500 g',
#      'quantity': 13,
#      'category': 'beverages'},
#     {'name': 'Health Drink',
#      'pricePerUnit': 28.0,
#      'unit': '75 g Pouch',
#      'quantity': 22,
#      'category': 'beverages'},
#     {'name': 'Beard Oil - Thyme',
#      'pricePerUnit': 295.0,
#      'unit': '30 ml',
#      'quantity': 17,
#      'category': 'beauty-hygiene'},
#     {'name': 'Diwali Diya',
#      'pricePerUnit': 50.0,
#      'unit': '2 pcs',
#      'quantity': 9,
#      'category': 'cleaning-household'},
#     {'name': 'Frozen Green Peas',
#      'pricePerUnit': 218.0,
#      'unit': '2x500 g (Multipack)',
#      'quantity': 22,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Infant Nail Scissors',
#      'pricePerUnit': 795.0,
#      'unit': '1 pc',
#      'quantity': 2,
#      'category': 'baby-care'},
#     {'name': 'Tea',
#      'pricePerUnit': 391.0,
#      'unit': '1 kg',
#      'quantity': 11,
#      'category': 'beverages'},
#     {'name': 'Chef Thai Red Curry',
#      'pricePerUnit': 149.0,
#      'unit': '240 g',
#      'quantity': 25,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Premium Wrap',
#      'pricePerUnit': 250.0,
#      'unit': '30cm X 20m',
#      'quantity': 17,
#      'category': 'cleaning-household'},
#     {'name': 'Chocochip Cookies',
#      'pricePerUnit': 73.0,
#      'unit': '4x75 g (Multipack)',
#      'quantity': 19,
#      'category': 'gourmet-world-food'},
#     {'name': 'Sugar',
#      'pricePerUnit': 224.0,
#      'unit': '5 kg',
#      'quantity': 12,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Cheese Garlic Bread',
#      'pricePerUnit': 40.0,
#      'unit': '300 g',
#      'quantity': 23,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Kitchen Towel',
#      'pricePerUnit': 178.0,
#      'unit': '4 pcs',
#      'quantity': 11,
#      'category': 'cleaning-household'},
#     {'name': 'Mega Chups Bulk',
#      'pricePerUnit': 1250.0,
#      'unit': '180 g',
#      'quantity': 12,
#      'category': 'gourmet-world-food'},
#     {'name': 'Brown Sugar',
#      'pricePerUnit': 67.0,
#      'unit': '500 g Pouch',
#      'quantity': 8,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'New York Cheese Cake',
#      'pricePerUnit': 284.0,
#      'unit': '200 g',
#      'quantity': 18,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Organic Cow Ghee',
#      'pricePerUnit': 567.0,
#      'unit': '500 ml',
#      'quantity': 24,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Choco Creme Biscuits',
#      'pricePerUnit': 81.0,
#      'unit': '3x120 g Multipack',
#      'quantity': 13,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Ash Gourd - Cut',
#      'pricePerUnit': 19.0,
#      'unit': '250 g',
#      'quantity': 10,
#      'category': 'fruits-vegetables'},
#     {'name': 'Choco Creme Biscuits',
#      'pricePerUnit': 81.0,
#      'unit': '3x120 g Multipack',
#      'quantity': 2,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Marshmallow',
#      'pricePerUnit': 150.0,
#      'unit': '160 g',
#      'quantity': 10,
#      'category': 'gourmet-world-food'},
#     {'name': 'Baby Lips Lip Balm',
#      'pricePerUnit': 140.0,
#      'unit': '4 g Cherry Kiss',
#      'quantity': 1,
#      'category': 'beauty-hygiene'},
#     {'name': 'Bread - Milk',
#      'pricePerUnit': 39.0,
#      'unit': '400 g Pouch',
#      'quantity': 0,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Multigrains Atta',
#      'pricePerUnit': 261.0,
#      'unit': '5 Kg Pouch',
#      'quantity': 14,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Salt - Iodised',
#      'pricePerUnit': 13.0,
#      'unit': '1 kg Pouch',
#      'quantity': 0,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Sparkling Eyeliner',
#      'pricePerUnit': 105.0,
#      'unit': '8 ml 01 White',
#      'quantity': 17,
#      'category': 'beauty-hygiene'},
#     {'name': 'Atta Bread',
#      'pricePerUnit': 45.0,
#      'unit': '400 g Pouch',
#      'quantity': 0,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Organic - Jaggery',
#      'pricePerUnit': 166.0,
#      'unit': '2x900 g Multipack',
#      'quantity': 0,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Cotton Buds',
#      'pricePerUnit': 56.0,
#      'unit': '100 pcs Box',
#      'quantity': 8,
#      'category': 'baby-care'},
#     {'name': 'Leaf Tea',
#      'pricePerUnit': 254.0,
#      'unit': '500 g',
#      'quantity': 7,
#      'category': 'beverages'},
#     {'name': 'Siah Jeera',
#      'pricePerUnit': 99.0,
#      'unit': '100 g',
#      'quantity': 8,
#      'category': 'gourmet-world-food'},
#     {'name': 'Badam Drink Mix',
#      'pricePerUnit': 220.0,
#      'unit': '500 g',
#      'quantity': 1,
#      'category': 'beverages'},
#     {'name': 'Baby Massage Oil',
#      'pricePerUnit': 375.0,
#      'unit': '500 ml',
#      'quantity': 13,
#      'category': 'baby-care'},
#     {'name': 'Organic Cow Ghee',
#      'pricePerUnit': 280.0,
#      'unit': '200 ml',
#      'quantity': 22,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Nail Enamel',
#      'pricePerUnit': 215.0,
#      'unit': '9 ml 06',
#      'quantity': 10,
#      'category': 'beauty-hygiene'},
#     {'name': 'Croissants - Cheese',
#      'pricePerUnit': 119.0,
#      'unit': '150 g (Pack of 2)',
#      'quantity': 8,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Butter Croissant',
#      'pricePerUnit': 107.0,
#      'unit': '100 g',
#      'quantity': 7,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'A2 Desi Ghee',
#      'pricePerUnit': 1200.0,
#      'unit': '500 ml',
#      'quantity': 19,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Face & Beard Wash',
#      'pricePerUnit': 117.0,
#      'unit': '80 ml',
#      'quantity': 17,
#      'category': 'beauty-hygiene'},
#     {'name': 'Curd - Artisanal',
#      'pricePerUnit': 80.0,
#      'unit': '400 g Cup',
#      'quantity': 25,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Capsicum - Yellow',
#      'pricePerUnit': 70.0,
#      'unit': '500 g',
#      'quantity': 10,
#      'category': 'fruits-vegetables'},
#     {'name': 'Sponge Brush - 2-Way',
#      'pricePerUnit': 325.0,
#      'unit': '1 pc',
#      'quantity': 9,
#      'category': 'baby-care'},
#     {'name': 'Sunrise Extra Sachet',
#      'pricePerUnit': 680.0,
#      'unit': '1 kg Pouch',
#      'quantity': 11,
#      'category': 'beverages'},
#     {'name': 'Latte Coffee Cup',
#      'pricePerUnit': 25.0,
#      'unit': '25 g',
#      'quantity': 10,
#      'category': 'beverages'},
#     {'name': 'Organic Sugar',
#      'pricePerUnit': 135.0,
#      'unit': '1 kg Pouch',
#      'quantity': 19,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Cotton Buds',
#      'pricePerUnit': 92.0,
#      'unit': '200 pcs Box',
#      'quantity': 7,
#      'category': 'baby-care'},
#     {'name': "Children's Shampoo",
#      'pricePerUnit': 927.0,
#      'unit': '500 ml',
#      'quantity': 24,
#      'category': 'baby-care'},
#     {'name': 'Strong Coffee',
#      'pricePerUnit': 68.0,
#      'unit': '50 g Can',
#      'quantity': 1,
#      'category': 'beverages'},
#     {'name': 'Gentle Baby Wash',
#      'pricePerUnit': 49.0,
#      'unit': '100 ml Bottle',
#      'quantity': 8,
#      'category': 'baby-care'},
#     {'name': 'Hand Rescue Cream',
#      'pricePerUnit': 239.0,
#      'unit': '50 g',
#      'quantity': 5,
#      'category': 'beauty-hygiene'},
#     {'name': 'Manicure Set In Case',
#      'pricePerUnit': 175.0,
#      'unit': '1 pc',
#      'quantity': 7,
#      'category': 'baby-care'},
#     {'name': 'Apple - Shimla',
#      'pricePerUnit': 59.0,
#      'unit': '4 pcs (Approx. 500g',
#      'quantity': 25,
#      'category': 'fruits-vegetables'},
#     {'name': 'Tea',
#      'pricePerUnit': 134.0,
#      'unit': '500 g',
#      'quantity': 14,
#      'category': 'beverages'},
#     {'name': 'Bread - Brown',
#      'pricePerUnit': 44.0,
#      'unit': '400 g Pouch',
#      'quantity': 6,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Milk Bikis Biscuits',
#      'pricePerUnit': 8.0,
#      'unit': '80 g',
#      'quantity': 20,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Natural Shine Henna',
#      'pricePerUnit': 67.0,
#      'unit': '120 g',
#      'quantity': 18,
#      'category': 'beauty-hygiene'},
#     {'name': 'Tortilla Wrap',
#      'pricePerUnit': 420.0,
#      'unit': '3x6 pcs Multipack',
#      'quantity': 5,
#      'category': 'gourmet-world-food'},
#     {'name': 'Infant Nail Scissors',
#      'pricePerUnit': 795.0,
#      'unit': '1 pc',
#      'quantity': 5,
#      'category': 'baby-care'},
#     {'name': 'Danish - Strawberry',
#      'pricePerUnit': 119.0,
#      'unit': '100 g Pack of 2',
#      'quantity': 18,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Tofu - Soya Paneer',
#      'pricePerUnit': 59.0,
#      'unit': '200 g',
#      'quantity': 13,
#      'category': 'gourmet-world-food'},
#     {'name': 'Glass Cleaner',
#      'pricePerUnit': 61.0,
#      'unit': '500 ml',
#      'quantity': 10,
#      'category': 'cleaning-household'},
#     {'name': 'Veggie Burger Patty',
#      'pricePerUnit': 125.0,
#      'unit': '360 g Pouch',
#      'quantity': 17,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Baby Bib - Girl, 0m+',
#      'pricePerUnit': 699.0,
#      'unit': '2 pcs',
#      'quantity': 23,
#      'category': 'baby-care'},
#     {'name': 'Jaggery Lump',
#      'pricePerUnit': 165.0,
#      'unit': '1 kg',
#      'quantity': 3,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Rich Moisture Bar',
#      'pricePerUnit': 51.0,
#      'unit': '75 g',
#      'quantity': 15,
#      'category': 'baby-care'},
#     {'name': 'Kitchen Cleaner',
#      'pricePerUnit': 110.0,
#      'unit': '500 ml',
#      'quantity': 14,
#      'category': 'cleaning-household'},
#     {'name': 'Milk Bread',
#      'pricePerUnit': 45.0,
#      'unit': '400 g Pouch',
#      'quantity': 18,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Marie Gold Biscuits',
#      'pricePerUnit': 14.0,
#      'unit': '120 g',
#      'quantity': 10,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Lip Balm - Soft Rose',
#      'pricePerUnit': 148.0,
#      'unit': '4.8 g',
#      'quantity': 9,
#      'category': 'beauty-hygiene'},
#     {'name': 'Strawberry Lip Balm',
#      'pricePerUnit': 149.0,
#      'unit': '10 g',
#      'quantity': 19,
#      'category': 'beauty-hygiene'},
#     {'name': 'Oil - Gingelly',
#      'pricePerUnit': 302.0,
#      'unit': '1 L Pouch',
#      'quantity': 16,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Dry Copra/Coconut',
#      'pricePerUnit': 54.0,
#      'unit': '1 pc Approx. 100',
#      'quantity': 14,
#      'category': 'fruits-vegetables'},
#     {'name': 'Sugar - Refined',
#      'pricePerUnit': 50.0,
#      'unit': '1 kg Pouch',
#      'quantity': 13,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Pumpkin Seeds',
#      'pricePerUnit': 73.0,
#      'unit': '100 g',
#      'quantity': 2,
#      'category': 'gourmet-world-food'},
#     {'name': 'Wheat Chapati',
#      'pricePerUnit': 70.0,
#      'unit': '350 g',
#      'quantity': 11,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Nacho Chips - Salsa',
#      'pricePerUnit': 23.0,
#      'unit': '60 g',
#      'quantity': 20,
#      'category': 'gourmet-world-food'},
#     {'name': 'Nail Polish Remover',
#      'pricePerUnit': 112.0,
#      'unit': '100 ml',
#      'quantity': 9,
#      'category': 'beauty-hygiene'},
#     {'name': 'Protectant Spray',
#      'pricePerUnit': 100.0,
#      'unit': '100 ml',
#      'quantity': 0,
#      'category': 'cleaning-household'},
#     {'name': 'Yam - Cut',
#      'pricePerUnit': 19.0,
#      'unit': '250 g',
#      'quantity': 0,
#      'category': 'fruits-vegetables'},
#     {'name': 'Clothes Pegs Clip',
#      'pricePerUnit': 159.0,
#      'unit': '12 pcs',
#      'quantity': 21,
#      'category': 'cleaning-household'},
#     {'name': 'Besan Burfi',
#      'pricePerUnit': 69.0,
#      'unit': '50 g',
#      'quantity': 15,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Oats - White',
#      'pricePerUnit': 170.0,
#      'unit': '1 kg Pouch',
#      'quantity': 20,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Chocolate Syrup',
#      'pricePerUnit': 194.0,
#      'unit': '623 g Bottle',
#      'quantity': 15,
#      'category': 'beverages'},
#     {'name': 'Band-Aid - Washproof',
#      'pricePerUnit': 25.0,
#      'unit': '10 pcs',
#      'quantity': 5,
#      'category': 'beauty-hygiene'},
#     {'name': 'Parwal',
#      'pricePerUnit': 88.0,
#      'unit': '500 g',
#      'quantity': 6,
#      'category': 'fruits-vegetables'},
#     {'name': 'Iodized',
#      'pricePerUnit': 17.0,
#      'unit': '1 kg Pouch',
#      'quantity': 23,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Malabar Parota',
#      'pricePerUnit': 75.0,
#      'unit': '350 g Pouch',
#      'quantity': 4,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Orange - Imported',
#      'pricePerUnit': 241.0,
#      'unit': '6 pcs',
#      'quantity': 24,
#      'category': 'fruits-vegetables'},
#     {'name': 'Coffee - Classic',
#      'pricePerUnit': 300.0,
#      'unit': '2x50 g Multipack',
#      'quantity': 14,
#      'category': 'beverages'},
#     {'name': 'Dipped Cookie',
#      'pricePerUnit': 111.0,
#      'unit': '2x150 g Multipack',
#      'quantity': 7,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Baby Lips Lip Balm',
#      'pricePerUnit': 140.0,
#      'unit': '4 g Cherry Kiss',
#      'quantity': 12,
#      'category': 'beauty-hygiene'},
#     {'name': 'Broccoli - Florets',
#      'pricePerUnit': 76.0,
#      'unit': '200 g',
#      'quantity': 4,
#      'category': 'fruits-vegetables'},
#     {'name': 'Leaf Tea',
#      'pricePerUnit': 514.0,
#      'unit': '1 kg',
#      'quantity': 15,
#      'category': 'beverages'},
#     {'name': 'Gel Effect',
#      'pricePerUnit': 316.0,
#      'unit': '8.5 ml 32 Coral',
#      'quantity': 0,
#      'category': 'beauty-hygiene'},
#     {'name': 'Tea - Natural Care',
#      'pricePerUnit': 49.0,
#      'unit': '100 g',
#      'quantity': 12,
#      'category': 'beverages'},
#     {'name': 'Coffee - Classic',
#      'pricePerUnit': 148.0,
#      'unit': '2x25 g Multipack',
#      'quantity': 10,
#      'category': 'beverages'},
#     {'name': 'Pure Olive Oil',
#      'pricePerUnit': 129.0,
#      'unit': '100 ml Bottle',
#      'quantity': 4,
#      'category': 'baby-care'},
#     {'name': 'Pooja Oil',
#      'pricePerUnit': 107.0,
#      'unit': '900 g',
#      'quantity': 22,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'True Wear Nail Color',
#      'pricePerUnit': 88.0,
#      'unit': '9 ml Shade 202',
#      'quantity': 18,
#      'category': 'beauty-hygiene'},
#     {'name': 'Leaf Tea',
#      'pricePerUnit': 485.0,
#      'unit': '1 kg',
#      'quantity': 23,
#      'category': 'beverages'},
#     {'name': 'Bread - Sandwich',
#      'pricePerUnit': 39.0,
#      'unit': '400 g Pouch',
#      'quantity': 20,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Olive Oil - Pure',
#      'pricePerUnit': 3098.0,
#      'unit': '5 L',
#      'quantity': 16,
#      'category': 'baby-care'},
#     {'name': 'Premium Toilet Brush',
#      'pricePerUnit': 449.0,
#      'unit': '1 pc',
#      'quantity': 16,
#      'category': 'cleaning-household'},
#     {'name': 'Cucumber - English',
#      'pricePerUnit': 22.0,
#      'unit': '500 g',
#      'quantity': 7,
#      'category': 'fruits-vegetables'},
#     {'name': 'Potato Cheese Shotz',
#      'pricePerUnit': 135.0,
#      'unit': '250 g',
#      'quantity': 7,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Sink Brush - Round',
#      'pricePerUnit': 69.0,
#      'unit': '1 pc',
#      'quantity': 17,
#      'category': 'cleaning-household'},
#     {'name': 'Nail Polish Thinner',
#      'pricePerUnit': 136.0,
#      'unit': '2x35 ml Multipack',
#      'quantity': 11,
#      'category': 'beauty-hygiene'},
#     {'name': 'Sweet Bread',
#      'pricePerUnit': 40.0,
#      'unit': '400 g',
#      'quantity': 25,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Cucumber - Sliced',
#      'pricePerUnit': 15.0,
#      'unit': '200 g',
#      'quantity': 18,
#      'category': 'fruits-vegetables'},
#     {'name': 'Aloo - Tikki',
#      'pricePerUnit': 170.0,
#      'unit': '760 g',
#      'quantity': 9,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Lavash - Beetroot',
#      'pricePerUnit': 58.0,
#      'unit': '100 g',
#      'quantity': 3,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Honey Oats Cookies',
#      'pricePerUnit': 99.0,
#      'unit': '4x75 g (Multipack)',
#      'quantity': 2,
#      'category': 'gourmet-world-food'},
#     {'name': 'Kiwi - Green',
#      'pricePerUnit': 83.0,
#      'unit': '3 pcs',
#      'quantity': 0,
#      'category': 'fruits-vegetables'},
#     {'name': 'Seeds - Chia',
#      'pricePerUnit': 314.0,
#      'unit': '200 g',
#      'quantity': 21,
#      'category': 'gourmet-world-food'},
#     {'name': 'Coccinia',
#      'pricePerUnit': 31.0,
#      'unit': '500 g',
#      'quantity': 17,
#      'category': 'fruits-vegetables'},
#     {'name': 'Cream Cheese',
#      'pricePerUnit': 200.0,
#      'unit': '150 g',
#      'quantity': 17,
#      'category': 'gourmet-world-food'},
#     {'name': 'Almond Milk - Cacao',
#      'pricePerUnit': 560.0,
#      'unit': '2x1 L Multipack',
#      'quantity': 14,
#      'category': 'gourmet-world-food'},
#     {'name': 'Darjeeling Tea',
#      'pricePerUnit': 414.0,
#      'unit': '250 g',
#      'quantity': 22,
#      'category': 'beverages'},
#     {'name': 'Nacho Chips - Cheese',
#      'pricePerUnit': 23.0,
#      'unit': '60 g',
#      'quantity': 22,
#      'category': 'gourmet-world-food'},
#     {'name': 'Long Point Sharpener',
#      'pricePerUnit': 100.0,
#      'unit': '20 pcs',
#      'quantity': 15,
#      'category': 'cleaning-household'},
#     {'name': 'Extract - Lavender',
#      'pricePerUnit': 399.0,
#      'unit': '110 ml',
#      'quantity': 10,
#      'category': 'gourmet-world-food'},
#     {'name': 'Capsicum - Diced',
#      'pricePerUnit': 25.0,
#      'unit': '200 g',
#      'quantity': 13,
#      'category': 'fruits-vegetables'},
#     {'name': 'Premium Wrap',
#      'pricePerUnit': 210.0,
#      'unit': '22cm X 20m',
#      'quantity': 5,
#      'category': 'cleaning-household'},
#     {'name': 'Dashboard Polish',
#      'pricePerUnit': 150.0,
#      'unit': '100 ml',
#      'quantity': 14,
#      'category': 'cleaning-household'},
#     {'name': 'Cotton Pads',
#      'pricePerUnit': 129.0,
#      'unit': '80 pcs (Get 30% Free)',
#      'quantity': 6,
#      'category': 'baby-care'},
#     {'name': 'Premium Coffee',
#      'pricePerUnit': 136.0,
#      'unit': '100 g Can',
#      'quantity': 19,
#      'category': 'beverages'},
#     {'name': 'Powder - Spirulina',
#      'pricePerUnit': 315.0,
#      'unit': '100 g',
#      'quantity': 24,
#      'category': 'gourmet-world-food'},
#     {'name': 'Strong Coffee',
#      'pricePerUnit': 206.0,
#      'unit': '200 g Pouch',
#      'quantity': 4,
#      'category': 'beverages'},
#     {'name': 'Hide and Seek',
#      'pricePerUnit': 25.0,
#      'unit': '250 gm',
#      'quantity': 50,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Pure Cow Ghee',
#      'pricePerUnit': 1390.0,
#      'unit': '2x1 L (Multipack)',
#      'quantity': 13,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Garlic - Peeled',
#      'pricePerUnit': 129.0,
#      'unit': '3x100 g Multipack',
#      'quantity': 8,
#      'category': 'fruits-vegetables'},
#     {'name': 'Gentle Baby Wash',
#      'pricePerUnit': 245.0,
#      'unit': '400 ml',
#      'quantity': 13,
#      'category': 'baby-care'},
#     {'name': 'Bagel - Plain',
#      'pricePerUnit': 55.0,
#      'unit': '250 g (Pack of 3)',
#      'quantity': 18,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Besan Burfi',
#      'pricePerUnit': 479.0,
#      'unit': '430 g',
#      'quantity': 20,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Pineapple - Slices',
#      'pricePerUnit': 49.0,
#      'unit': '200 g',
#      'quantity': 16,
#      'category': 'fruits-vegetables'},
#     {'name': 'Gentle Baby Soap',
#      'pricePerUnit': 65.0,
#      'unit': '125 g',
#      'quantity': 8,
#      'category': 'baby-care'},
#     {'name': 'Nail Enamel N Series',
#      'pricePerUnit': 136.0,
#      'unit': '2x7 ml Multipack',
#      'quantity': 7,
#      'category': 'beauty-hygiene'},
#     {'name': 'Baby Wash Top-To-Toe',
#      'pricePerUnit': 150.0,
#      'unit': '200 ml',
#      'quantity': 3,
#      'category': 'baby-care'},
#     {'name': 'Sambar Sadam',
#      'pricePerUnit': 115.0,
#      'unit': '72 g Tub',
#      'quantity': 14,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Dishwash Liquid',
#      'pricePerUnit': 120.0,
#      'unit': '6X120 ml Multipack',
#      'quantity': 24,
#      'category': 'cleaning-household'},
#     {'name': 'Watermelon  - Small',
#      'pricePerUnit': 42.0,
#      'unit': '1 pc 1.7',
#      'quantity': 1,
#      'category': 'fruits-vegetables'},
#     {'name': 'Pumpkin Green - Cut',
#      'pricePerUnit': 33.0,
#      'unit': '500 g',
#      'quantity': 4,
#      'category': 'fruits-vegetables'},
#     {'name': 'Chana Burfi',
#      'pricePerUnit': 79.0,
#      'unit': '50 g',
#      'quantity': 2,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Coconut - Diced',
#      'pricePerUnit': 38.0,
#      'unit': '150 g',
#      'quantity': 18,
#      'category': 'fruits-vegetables'},
#     {'name': 'Jaggery - Kolhapuri',
#      'pricePerUnit': 83.0,
#      'unit': '900 g',
#      'quantity': 16,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Food Package - Small',
#      'pricePerUnit': 35.0,
#      'unit': '250 ml Pack of 10',
#      'quantity': 5,
#      'category': 'cleaning-household'},
#     {'name': 'Good Day',
#      'pricePerUnit': 15.0,
#      'unit': '250 gm',
#      'quantity': 25,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Fruit Bread',
#      'pricePerUnit': 16.0,
#      'unit': '200 g Pouch',
#      'quantity': 13,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Buds',
#      'pricePerUnit': 45.0,
#      'unit': '30 stems/60 swabs',
#      'quantity': 3,
#      'category': 'baby-care'},
#     {'name': 'Bringha Oil',
#      'pricePerUnit': 388.0,
#      'unit': '100 ml',
#      'quantity': 10,
#      'category': 'beauty-hygiene'},
#     {'name': 'Tea',
#      'pricePerUnit': 130.0,
#      'unit': '250 g Pouch',
#      'quantity': 21,
#      'category': 'beverages'},
#     {'name': 'Bread - Multigrain',
#      'pricePerUnit': 49.0,
#      'unit': '400 g Pouch',
#      'quantity': 19,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Soan Papdi',
#      'pricePerUnit': 120.0,
#      'unit': '500 g Pouch',
#      'quantity': 22,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Food Safe Wipes',
#      'pricePerUnit': 126.0,
#      'unit': '30 pcs',
#      'quantity': 24,
#      'category': 'cleaning-household'},
#     {'name': "Children's Shampoo",
#      'pricePerUnit': 927.0,
#      'unit': '500 ml',
#      'quantity': 17,
#      'category': 'baby-care'},
#     {'name': 'Multigrain Bread',
#      'pricePerUnit': 50.0,
#      'unit': '450 g Pouch',
#      'quantity': 16,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Manicure Set In Case',
#      'pricePerUnit': 175.0,
#      'unit': '1 pc',
#      'quantity': 13,
#      'category': 'baby-care'},
#     {'name': 'Baby Corn - Peeled',
#      'pricePerUnit': 50.0,
#      'unit': '250 g',
#      'quantity': 9,
#      'category': 'fruits-vegetables'},
#     {'name': 'Capsicum - Green',
#      'pricePerUnit': 28.0,
#      'unit': '500 g',
#      'quantity': 6,
#      'category': 'fruits-vegetables'},
#     {'name': 'Rainbow Cake',
#      'pricePerUnit': 284.0,
#      'unit': '200 g',
#      'quantity': 18,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Glass Cleaner',
#      'pricePerUnit': 89.0,
#      'unit': '500 ml',
#      'quantity': 18,
#      'category': 'cleaning-household'},
#     {'name': 'Croissants - Butter',
#      'pricePerUnit': 109.0,
#      'unit': '150 g (Pack of 2)',
#      'quantity': 19,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Organic Oats Powder',
#      'pricePerUnit': 201.0,
#      'unit': '250 g',
#      'quantity': 22,
#      'category': 'baby-care'},
#     {'name': 'Wipes - Gentle Baby',
#      'pricePerUnit': 183.0,
#      'unit': '72 pcs Pouch',
#      'quantity': 1,
#      'category': 'baby-care'},
#     {'name': 'Color Crush Nail Art',
#      'pricePerUnit': 131.0,
#      'unit': '6 ml G1',
#      'quantity': 8,
#      'category': 'beauty-hygiene'},
#     {'name': 'Organic - Castor Oil',
#      'pricePerUnit': 120.0,
#      'unit': '250 ml Bottle',
#      'quantity': 17,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Seeds Mix',
#      'pricePerUnit': 93.0,
#      'unit': '2x50 g Multipack',
#      'quantity': 15,
#      'category': 'gourmet-world-food'},
#     {'name': 'Premium Coffee',
#      'pricePerUnit': 70.0,
#      'unit': '50 g Pouch',
#      'quantity': 10,
#      'category': 'beverages'},
#     {'name': 'Tea - Natural Care',
#      'pricePerUnit': 179.0,
#      'unit': '250 g',
#      'quantity': 10,
#      'category': 'beverages'},
#     {'name': 'Classic Coffee',
#      'pricePerUnit': 486.0,
#      'unit': '200 g Glass Jar',
#      'quantity': 8,
#      'category': 'beverages'},
#     {'name': 'Peach Shine Lip Care',
#      'pricePerUnit': 135.0,
#      'unit': '4.5 g',
#      'quantity': 1,
#      'category': 'beauty-hygiene'},
#     {'name': 'Frozen - Sweet Corn',
#      'pricePerUnit': 40.0,
#      'unit': '200 g Pouch',
#      'quantity': 16,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Dishwash - Kraft',
#      'pricePerUnit': 139.0,
#      'unit': '750 ml',
#      'quantity': 3,
#      'category': 'cleaning-household'},
#     {'name': 'Baby Happy Tissues',
#      'pricePerUnit': 150.0,
#      'unit': '9 pcs (Pack of 10)',
#      'quantity': 25,
#      'category': 'baby-care'},
#     {'name': 'Cloth Clip',
#      'pricePerUnit': 240.0,
#      'unit': '24 pcs',
#      'quantity': 23,
#      'category': 'cleaning-household'},
#     {'name': 'Cooking Sheet',
#      'pricePerUnit': 179.0,
#      'unit': '30cm X 5m',
#      'quantity': 11,
#      'category': 'cleaning-household'},
#     {'name': 'Waffy Choco Roll',
#      'pricePerUnit': 91.0,
#      'unit': '250 g',
#      'quantity': 11,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Ragi Crackers',
#      'pricePerUnit': 90.0,
#      'unit': '100 g Pouch',
#      'quantity': 4,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Refined Sugar',
#      'pricePerUnit': 320.0,
#      'unit': '5 kg Pouch',
#      'quantity': 25,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Croissant',
#      'pricePerUnit': 90.0,
#      'unit': '65 g',
#      'quantity': 18,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Ecostay Nail Enamel',
#      'pricePerUnit': 169.0,
#      'unit': '10 ml Raspberry Wine',
#      'quantity': 16,
#      'category': 'beauty-hygiene'},
#     {'name': 'Select Atta',
#      'pricePerUnit': 238.0,
#      'unit': '5 Kg Pouch',
#      'quantity': 12,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Top Ramen',
#      'pricePerUnit': 70.0,
#      'unit': '480 gm',
#      'quantity': 25,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Pomegranate',
#      'pricePerUnit': 168.0,
#      'unit': '4 pcs (approx. 720 to 800 gm)',
#      'quantity': 20,
#      'category': 'fruits-vegetables'},
#     {'name': 'Jaggery Round',
#      'pricePerUnit': 67.0,
#      'unit': '1 kg',
#      'quantity': 25,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Beard Butter Balm',
#      'pricePerUnit': 319.0,
#      'unit': '50 g',
#      'quantity': 0,
#      'category': 'beauty-hygiene'},
#     {'name': 'Bread - Fruit',
#      'pricePerUnit': 20.0,
#      'unit': '150 g Pouch',
#      'quantity': 14,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Atta - Whole Wheat',
#      'pricePerUnit': 376.0,
#      'unit': '10 kg Pouch',
#      'quantity': 24,
#      'category': 'foodgrains-oil-masala'},
#     {'name': 'Chia Seeds',
#      'pricePerUnit': 175.0,
#      'unit': '100 g',
#      'quantity': 22,
#      'category': 'gourmet-world-food'},
#     {'name': 'Atta Bread',
#      'pricePerUnit': 45.0,
#      'unit': '400 g',
#      'quantity': 14,
#      'category': 'bakery-cakes-dairy'},
#     {'name': 'Tea - Strong',
#      'pricePerUnit': 218.0,
#      'unit': '1 kg',
#      'quantity': 16,
#      'category': 'beverages'},
#     {'name': 'True Wear Nail Color',
#      'pricePerUnit': 88.0,
#      'unit': '9 ml Shade 202',
#      'quantity': 7,
#      'category': 'beauty-hygiene'},
#     {'name': 'Nuggets - Chicken',
#      'pricePerUnit': 248.0,
#      'unit': '500 g Pouch',
#      'quantity': 25,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Soan Papdi',
#      'pricePerUnit': 780.0,
#      'unit': '12x250 g Multipack',
#      'quantity': 6,
#      'category': 'snacks-branded-foods'},
#     {'name': 'Skin Care Wipes',
#      'pricePerUnit': 67.0,
#      'unit': '20 pcs',
#      'quantity': 4,
#      'category': 'baby-care'},
#     {'name': 'Lite',
#      'pricePerUnit': 32.0,
#      'unit': '1 kg Pouch',
#      'quantity': 15,
#      'category': 'foodgrains-oil-masala'}]},
#   'gstin': '363829202739'}}

# %%
customerData = {
    "customer_id" : data["customer"]["id"],
    'customer_income': data["customer"]['annualIncome'],
    'customer_electricity_bill': data["customer"]['electricityBill'],
    'residence_latitude': data["customer"]['residenceAddress']['latitude'],
    'residence_longitude': data["customer"]['residenceAddress']['longitude'],
    'customer_cibil': data['customer']['cibilScore'],
    'customer_status': data['customer']['status'],
    'customer_verified': data['customer']['verified'],
    'gurantor_income': data['instantLoanSurrogates']['guarantor']['annualIncome'] if data['instantLoanSurrogates']['guarantor'] else 0,
    'gurantor_electricity_bill': data['instantLoanSurrogates']['guarantor']['electricityBill'] if data['instantLoanSurrogates']['guarantor'] else 0,
    'gurantor_worthy': data['instantLoanSurrogates']['guarantor']['worthy'] if data['instantLoanSurrogates']['guarantor'] else 0,
    'gurantor_cibil': data['instantLoanSurrogates']['guarantor']['cibilScore'] if data['instantLoanSurrogates']['guarantor'] else 0,
    'gurantor_residence_latitude': data['instantLoanSurrogates']["guarantor"]['residenceAddress']['latitude'] if data['instantLoanSurrogates']['guarantor'] else 0,
    'gurantor_residence_longitude': data['instantLoanSurrogates']["guarantor"]['residenceAddress']['longitude'] if data['instantLoanSurrogates']['guarantor'] else 0,
    'location_category': data['instantLoanSurrogates']['locationCategory'],
    'competition': data['instantLoanSurrogates']['competition'],
    'taxReturns': sum(i['tax'] for i in data['instantLoanSurrogates']['taxReturns']),
    'credit': sum(i['creditAmount'] for i in data['instantLoanSurrogates']['creditAmountOfShopCustomers']) if data['instantLoanSurrogates']['creditAmountOfShopCustomers'] else 0,
    'bank_account': sum(i['currentValue'] if i['currentValue'] else 0 for i in data["allBankAccounts"]),
    'shop_latitude': data["shop"]['shopAddress']['latitude'],
    'shop_longitude': data["shop"]['shopAddress']['longitude'],
    'shop_area': data["shop"]['area'],
    'shop_rating': data["shop"]['rating'],
    'shop_electricity_bill': data["shop"]['electricityAmount'],
    'shop_ownership': data["shop"]['ownership'],
    'shop_warehouse_number': data["shop"]['wareHouse']['numberOfWareHouses'],
    'shop_warehouse_area': sum(data["shop"]['wareHouse']['areaOfWareHouses']) / data["shop"]['wareHouse']['numberOfWareHouses'],
    'items': sum(product['quantity'] * product['pricePerUnit'] for product in data["shop"]['wareHouse']['itemsSet']),
    'loan_amount': data['allLoans'][-1]['demandedAmount'],
}

customerData
# Out:
# {'customer_id': 1,
#  'customer_income': 100000.0,
#  'customer_electricity_bill': 1996.0,
#  'residence_latitude': 22.7681,
#  'residence_longitude': 75.8981,
#  'customer_cibil': None,
#  'customer_status': 7,
#  'customer_verified': None,
#  'gurantor_income': 150.0,
#  'gurantor_electricity_bill': 4500.0,
#  'gurantor_worthy': None,
#  'gurantor_cibil': None,
#  'gurantor_residence_latitude': 22.7422,
#  'gurantor_residence_longitude': 75.8947,
#  'location_category': None,
#  'competition': None,
#  'taxReturns': 0.0,
#  'credit': 0,
#  'bank_account': 0,
#  'shop_latitude': 22.7606,
#  'shop_longitude': 75.8912,
#  'shop_area': 500.0,
#  'shop_rating': None,
#  'shop_electricity_bill': 1996.0,
#  'shop_ownership': 'PURCHASED',
#  'shop_warehouse_number': 1,
#  'shop_warehouse_area': 500.0,
#  'items': 735750.0,
#  'loan_amount': 50000.0}

# %%
list(customerData.keys())
# Out:
# ['customer_id',
#  'customer_income',
#  'customer_electricity_bill',
#  'residence_latitude',
#  'residence_longitude',
#  'customer_cibil',
#  'customer_status',
#  'customer_verified',
#  'gurantor_income',
#  'gurantor_electricity_bill',
#  'gurantor_worthy',
#  'gurantor_cibil',
#  'gurantor_residence_latitude',
#  'gurantor_residence_longitude',
#  'location_category',
#  'competition',
#  'taxReturns',
#  'credit',
#  'bank_account',
#  'shop_latitude',
#  'shop_longitude',
#  'shop_area',
#  'shop_rating',
#  'shop_electricity_bill',
#  'shop_ownership',
#  'shop_warehouse_number',
#  'shop_warehouse_area',
#  'items',
#  'loan_amount']

# %%
list(customerData.values())
# Out:
# [1,
#  100000.0,
#  1996.0,
#  22.7681,
#  75.8981,
#  None,
#  7,
#  None,
#  150.0,
#  4500.0,
#  None,
#  None,
#  22.7422,
#  75.8947,
#  None,
#  None,
#  0.0,
#  0,
#  0,
#  22.7606,
#  75.8912,
#  500.0,
#  None,
#  1996.0,
#  'PURCHASED',
#  1,
#  500.0,
#  735750.0,
#  50000.0]

# %%
customerDf = pd.DataFrame([customerData.values()], columns=customerData.keys())
customerDf
# Out:
#    customer_id  customer_income  customer_electricity_bill  \
# 0            1         100000.0                     1996.0
#
#    residence_latitude  residence_longitude customer_cibil  customer_status  \
# 0             22.7681              75.8981           None                7
#
#   customer_verified  gurantor_income  gurantor_electricity_bill  ...  \
# 0              None            150.0                     4500.0  ...
#
#   shop_latitude shop_longitude  shop_area  shop_rating shop_electricity_bill  \
# 0       22.7606        75.8912      500.0         None                1996.0
#
#   shop_ownership  shop_warehouse_number  shop_warehouse_area     items  \
# 0      PURCHASED                      1                500.0  735750.0
#
#    loan_amount
# 0      50000.0
#
# [1 rows x 29 columns]

# %%
loan_data = pd.read_csv('loan.csv')
loan_data.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# 1     17.0     0.0   20131.0       53.3      27.0                    f
# 2     13.0     0.0   11987.0       92.2      26.0                    f
# 3      6.0     0.0    5472.0       21.5      13.0                    f
# 4     13.0     0.0   24584.0       69.8      43.0                    f
#
#   application_type  mort_acc  pub_rec_bankruptcies  \
# 0       INDIVIDUAL       0.0                   0.0
# 1       INDIVIDUAL       3.0                   0.0
# 2       INDIVIDUAL       0.0                   0.0
# 3       INDIVIDUAL       0.0                   0.0
# 4       INDIVIDUAL       1.0                   0.0
#
#                                              address
# 0     0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1  1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2  87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3            823 Reid Ford\r\nDelacruzside, MA 00813
# 4             679 Luna Roads\r\nGreggshire, VA 11650
#
# [5 rows x 27 columns]

# %%
loan_data.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'title',
#        'dti', 'earliest_cr_line', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'application_type',
#        'mort_acc', 'pub_rec_bankruptcies', 'address'],
#       dtype='object')

# %%
for i in tqdm(range(500)):
    customerDf.at[i,'customer_id'] = i+1
    customerDf.at[i,'customer_income'] = loan_data.at[i,'annual_inc']
    customerDf.at[i,'gurantor_income'] = loan_data.at[i,'annual_inc']*round(random.uniform(0, 1),4)
    customerDf.at[i,'shop_ownership'] = loan_data.at[i,'home_ownership']
    customerDf.at[i,'customer_verified'] = loan_data.at[i,'verification_status']
    customerDf.at[i,'bank_account'] = loan_data.at[i,'total_acc']*10000
    customerDf.at[i,'loan_status'] = loan_data.at[i,'loan_status']
    customerDf.at[i,'residence_latitude'] = round(random.uniform(22.614544, 22.799159),8)
    customerDf.at[i,'residence_longitude'] = round(random.uniform(75.792446, 75.941390),8)
    customerDf.at[i,'shop_latitude'] = round(random.uniform(22.614544, 22.799159),8)
    customerDf.at[i,'shop_longitude'] = round(random.uniform(75.792446, 75.941390),8)
    customerDf.at[i,'gurantor_residence_latitude'] = round(random.uniform(22.614544, 22.799159),8)
    customerDf.at[i,'gurantor_residence_longitude'] = round(random.uniform(75.792446, 75.941390),8)
    customerDf.at[i,'customer_cibil'] = int(random.uniform(100, 300))
    customerDf.at[i,'gurantor_cibil'] = int(random.uniform(100, 900))
    customerDf.at[i,'customer_status'] = 7
    customerDf.at[i,'shop_rating'] = int(random.uniform(1, 5))
    customerDf.at[i,'location_category'] = int(random.uniform(0, 2))
    customerDf.at[i,'shop_warehouse_number'] = int(random.uniform(1, 8))
    customerDf.at[i,'shop_area'] = round(random.uniform(200, 1000),2)
    customerDf.at[i,'shop_warehouse_area'] = round(random.uniform(200, 1000),2)
    customerDf.at[i,'customer_electricity_bill'] = round(random.uniform(200, 2000),2)
    customerDf.at[i,'gurantor_electricity_bill'] = round(random.uniform(200, 2000),2)
    customerDf.at[i,'shop_electricity_bill'] = round(random.uniform(200, 1000),2)
    customerDf.at[i,'items'] = round(random.uniform(100000, 1000000),2)
    customerDf.at[i,'loan_amount'] = round(random.uniform(50000, 1000000),2)
    customerDf.at[i,'credit'] = round(random.uniform(200, 1000),2)
    customerDf.at[i,'taxReturns'] = round(random.uniform(10000, 100000),2)
    customerDf.at[i,'gurantor_worthy'] = int(random.uniform(0, 1))
    
customerDf.head()
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 553.97it/s]
#    customer_id  customer_income  customer_electricity_bill  \
# 0          1.0         117000.0                     684.56
# 1          2.0          65000.0                    1121.36
# 2          3.0          43057.0                    1445.99
# 3          4.0          54000.0                     774.16
# 4          5.0          55000.0                    1112.11
#
#    residence_latitude  residence_longitude customer_cibil  customer_status  \
# 0           22.646895            75.937585            130              7.0
# 1           22.725705            75.806820            195              7.0
# 2           22.644733            75.928098            269              7.0
# 3           22.774592            75.867280            273              7.0
# 4           22.701412            75.880464            196              7.0
#
#   customer_verified  gurantor_income  gurantor_electricity_bill  ...  \
# 0      Not Verified        3872.7000                     397.15  ...
# 1      Not Verified       11342.5000                    1531.46  ...
# 2   Source Verified       30079.6202                     227.97  ...
# 3      Not Verified       17101.8000                     216.86  ...
# 4          Verified       42421.5000                     233.75  ...
#
#   shop_longitude shop_area  shop_rating  shop_electricity_bill shop_ownership  \
# 0      75.829513    339.10            1                 896.08           RENT
# 1      75.805212    266.54            2                 232.92       MORTGAGE
# 2      75.869066    827.52            2                 625.30           RENT
# 3      75.827732    228.63            4                 947.46           RENT
# 4      75.900409    986.47            3                 568.32       MORTGAGE
#
#   shop_warehouse_number  shop_warehouse_area      items  loan_amount  \
# 0                   5.0               229.77  937293.45    939112.86
# 1                   7.0               458.44  434799.11    128789.42
# 2                   5.0               390.14  134761.99    177013.90
# 3                   4.0               621.39  348424.47    611720.42
# 4                   1.0               909.69  870811.07    449732.51
#
#    loan_status
# 0   Fully Paid
# 1   Fully Paid
# 2   Fully Paid
# 3   Fully Paid
# 4  Charged Off
#
# [5 rows x 30 columns]

# %%
customerDf = customerDf.fillna(0)
customerDf
# Out:
#      customer_id  customer_income  customer_electricity_bill  \
# 0            1.0         117000.0                     684.56
# 1            2.0          65000.0                    1121.36
# 2            3.0          43057.0                    1445.99
# 3            4.0          54000.0                     774.16
# 4            5.0          55000.0                    1112.11
# ..           ...              ...                        ...
# 495        496.0          65000.0                     807.26
# 496        497.0          68000.0                     240.52
# 497        498.0          61000.0                    1609.20
# 498        499.0          42000.0                    1823.31
# 499        500.0          70000.0                    1425.91
#
#      residence_latitude  residence_longitude  customer_cibil  customer_status  \
# 0             22.646895            75.937585             130              7.0
# 1             22.725705            75.806820             195              7.0
# 2             22.644733            75.928098             269              7.0
# 3             22.774592            75.867280             273              7.0
# 4             22.701412            75.880464             196              7.0
# ..                  ...                  ...             ...              ...
# 495           22.700362            75.833474             188              7.0
# 496           22.719236            75.835989             275              7.0
# 497           22.749630            75.906501             204              7.0
# 498           22.673539            75.895580             227              7.0
# 499           22.789437            75.863628             200              7.0
#
#     customer_verified  gurantor_income  gurantor_electricity_bill  ...  \
# 0        Not Verified        3872.7000                     397.15  ...
# 1        Not Verified       11342.5000                    1531.46  ...
# 2     Source Verified       30079.6202                     227.97  ...
# 3        Not Verified       17101.8000                     216.86  ...
# 4            Verified       42421.5000                     233.75  ...
# ..                ...              ...                        ...  ...
# 495          Verified       29588.0000                     941.72  ...
# 496      Not Verified       51251.6000                     941.63  ...
# 497          Verified       20087.3000                    1401.77  ...
# 498      Not Verified        4695.6000                     608.90  ...
# 499      Not Verified       69692.0000                     930.15  ...
#
#      shop_longitude  shop_area  shop_rating  shop_electricity_bill  \
# 0         75.829513     339.10            1                 896.08
# 1         75.805212     266.54            2                 232.92
# 2         75.869066     827.52            2                 625.30
# 3         75.827732     228.63            4                 947.46
# 4         75.900409     986.47            3                 568.32
# ..              ...        ...          ...                    ...
# 495       75.923977     355.01            4                 666.83
# 496       75.904843     445.08            2                 585.26
# 497       75.894449     912.56            2                 485.06
# 498       75.798019     257.32            2                 708.71
# 499       75.925879     982.69            3                 872.43
#
#      shop_ownership  shop_warehouse_number  shop_warehouse_area      items  \
# 0              RENT                    5.0               229.77  937293.45
# 1          MORTGAGE                    7.0               458.44  434799.11
# 2              RENT                    5.0               390.14  134761.99
# 3              RENT                    4.0               621.39  348424.47
# 4          MORTGAGE                    1.0               909.69  870811.07
# ..              ...                    ...                  ...        ...
# 495            RENT                    6.0               758.06  413711.08
# 496            RENT                    1.0               621.08  735413.33
# 497        MORTGAGE                    1.0               755.05  276663.74
# 498        MORTGAGE                    1.0               269.06  774823.87
# 499        MORTGAGE                    2.0               460.61  668795.44
#
#      loan_amount  loan_status
# 0      939112.86   Fully Paid
# 1      128789.42   Fully Paid
# 2      177013.90   Fully Paid
# 3      611720.42   Fully Paid
# 4      449732.51  Charged Off
# ..           ...          ...
# 495    505474.34   Fully Paid
# 496    245122.49   Fully Paid
# 497    373220.98   Fully Paid
# 498    318155.34   Fully Paid
# 499    580353.56   Fully Paid
#
# [500 rows x 30 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
customerDf['customer_verified'] = labelencoder.fit_transform(customerDf['customer_verified'])
customerDf['shop_ownership'] = labelencoder.fit_transform(customerDf['shop_ownership'])
customerDf['loan_status'] = labelencoder.fit_transform(customerDf['loan_status'])

customerDf
# Out:
#      customer_id  customer_income  customer_electricity_bill  \
# 0            1.0         117000.0                     684.56
# 1            2.0          65000.0                    1121.36
# 2            3.0          43057.0                    1445.99
# 3            4.0          54000.0                     774.16
# 4            5.0          55000.0                    1112.11
# ..           ...              ...                        ...
# 495        496.0          65000.0                     807.26
# 496        497.0          68000.0                     240.52
# 497        498.0          61000.0                    1609.20
# 498        499.0          42000.0                    1823.31
# 499        500.0          70000.0                    1425.91
#
#      residence_latitude  residence_longitude  customer_cibil  customer_status  \
# 0             22.646895            75.937585             130              7.0
# 1             22.725705            75.806820             195              7.0
# 2             22.644733            75.928098             269              7.0
# 3             22.774592            75.867280             273              7.0
# 4             22.701412            75.880464             196              7.0
# ..                  ...                  ...             ...              ...
# 495           22.700362            75.833474             188              7.0
# 496           22.719236            75.835989             275              7.0
# 497           22.749630            75.906501             204              7.0
# 498           22.673539            75.895580             227              7.0
# 499           22.789437            75.863628             200              7.0
#
#      customer_verified  gurantor_income  gurantor_electricity_bill  ...  \
# 0                    0        3872.7000                     397.15  ...
# 1                    0       11342.5000                    1531.46  ...
# 2                    1       30079.6202                     227.97  ...
# 3                    0       17101.8000                     216.86  ...
# 4                    2       42421.5000                     233.75  ...
# ..                 ...              ...                        ...  ...
# 495                  2       29588.0000                     941.72  ...
# 496                  0       51251.6000                     941.63  ...
# 497                  2       20087.3000                    1401.77  ...
# 498                  0        4695.6000                     608.90  ...
# 499                  0       69692.0000                     930.15  ...
#
#      shop_longitude  shop_area  shop_rating  shop_electricity_bill  \
# 0         75.829513     339.10            1                 896.08
# 1         75.805212     266.54            2                 232.92
# 2         75.869066     827.52            2                 625.30
# 3         75.827732     228.63            4                 947.46
# 4         75.900409     986.47            3                 568.32
# ..              ...        ...          ...                    ...
# 495       75.923977     355.01            4                 666.83
# 496       75.904843     445.08            2                 585.26
# 497       75.894449     912.56            2                 485.06
# 498       75.798019     257.32            2                 708.71
# 499       75.925879     982.69            3                 872.43
#
#      shop_ownership  shop_warehouse_number  shop_warehouse_area      items  \
# 0                 2                    5.0               229.77  937293.45
# 1                 0                    7.0               458.44  434799.11
# 2                 2                    5.0               390.14  134761.99
# 3                 2                    4.0               621.39  348424.47
# 4                 0                    1.0               909.69  870811.07
# ..              ...                    ...                  ...        ...
# 495               2                    6.0               758.06  413711.08
# 496               2                    1.0               621.08  735413.33
# 497               0                    1.0               755.05  276663.74
# 498               0                    1.0               269.06  774823.87
# 499               0                    2.0               460.61  668795.44
#
#      loan_amount  loan_status
# 0      939112.86            1
# 1      128789.42            1
# 2      177013.90            1
# 3      611720.42            1
# 4      449732.51            0
# ..           ...          ...
# 495    505474.34            1
# 496    245122.49            1
# 497    373220.98            1
# 498    318155.34            1
# 499    580353.56            1
#
# [500 rows x 30 columns]

# %%
X = customerDf.drop("loan_amount",axis=1)
y = customerDf["loan_amount"]

# %%
from sklearn.model_selection import train_test_split, learning_curve, validation_curve, cross_val_score, GridSearchCV

# %%
# from sklearn.preprocessing import PolynomialFeatures
# X = PolynomialFeatures(degree=3, include_bias=False).fit_transform(X)
# X

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.33, shuffle = True,
                                                   random_state = 0)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((165, 29), (335, 29), (165,), (335,))

# %%
X_train.head()
# Out:
#      customer_id  customer_income  customer_electricity_bill  \
# 125        126.0          70000.0                    1785.43
# 280        281.0          50000.0                    1981.61
# 286        287.0         495000.0                    1651.71
# 77          78.0         135000.0                     904.85
# 184        185.0          62000.0                     447.02
#
#      residence_latitude  residence_longitude  customer_cibil  customer_status  \
# 125           22.760677            75.828041             185              7.0
# 280           22.650445            75.833323             293              7.0
# 286           22.665334            75.811036             272              7.0
# 77            22.779141            75.906165             212              7.0
# 184           22.687166            75.802966             170              7.0
#
#      customer_verified  gurantor_income  gurantor_electricity_bill  ...  \
# 125                  2          52255.0                     606.78  ...
# 280                  1           3095.0                    1756.91  ...
# 286                  1          62914.5                     723.42  ...
# 77                   2          20614.5                    1188.06  ...
# 184                  2          26046.2                     656.59  ...
#
#      shop_latitude  shop_longitude  shop_area  shop_rating  \
# 125      22.692824       75.841634     943.21            4
# 280      22.711667       75.825079     860.73            2
# 286      22.682454       75.908018     734.20            4
# 77       22.767794       75.803994     721.28            3
# 184      22.735157       75.909833     606.34            4
#
#      shop_electricity_bill  shop_ownership  shop_warehouse_number  \
# 125                 919.23               2                    2.0
# 280                 338.83               2                    1.0
# 286                 688.99               1                    2.0
# 77                  284.05               2                    3.0
# 184                 398.47               2                    6.0
#
#      shop_warehouse_area      items  loan_status
# 125               439.54  354212.18            1
# 280               214.41  194624.57            1
# 286               272.51  262658.62            1
# 77                317.89  166224.05            1
# 184               360.35  999834.93            1
#
# [5 rows x 29 columns]

# %%
from sklearn.linear_model import LinearRegression

linreg = LinearRegression()
linreg.fit(X_train, y_train)
y_pred = linreg.predict(X_test)
y_pred
# Out:
# array([548760.55440506, 703565.98648054, 790634.06265333, 585552.77557349,
#        751686.97875429, 404919.20287245, 414869.28935051, 681470.1872046 ,
#        563238.93205032, 670319.14074091, 405518.9244782 , 558551.9188863 ,
#        260688.43475471, 528249.12285792, 438473.21404323, 556388.5788981 ,
#        418265.52846029, 732552.45311169, 309774.93850556, 553284.96531628,
#        648318.52547717, 670460.09172027, 464961.56709826, 544898.76134691,
#        441090.61867554, 649785.15666514, 422805.56589748, 538282.40008272,
#        502005.57905457, 422683.42242875, 428572.11518383, 768114.19406531,
#        329635.86726406, 575227.69160195, 617686.59615588, 840639.74983658,
#        615717.83927524, 621072.62102695, 406306.66145578, 708391.51726201,
#        554976.68765548, 467704.44635704, 671573.47828971, 672157.20256088,
#        199004.86646559, 439813.50705164, 970757.02977086, 551728.68991097,
#        804405.16399295, 585419.58774318, 552494.02569478, 608739.31622854,
#        604928.34980083, 660534.12455104, 890702.01930288, 315862.70617951,
#        531549.93367428, 609652.82606887, 575359.6838818 , 657613.78821153,
#        501770.58086199, 692696.13898702, 420086.17593816, 437148.54093214,
#        403051.50492758, 592529.9948063 , 771788.75805374, 727083.71689091,
#        477881.39641088, 527003.50161011, 340127.87773012, 643927.42904902,
#        718893.64680968, 693986.22094639, 533199.33841313, 703109.70454542,
#        512929.07248101, 534156.138641  , 548851.01157597, 394712.9982638 ,
#        601082.45752672, 383517.32900074, 645641.20069512, 572176.05578078,
#        707173.86127959, 414661.08517143, 714213.36104212, 510214.43768617,
#        380798.49917888, 448601.7664385 , 211125.9991428 , 424445.69276266,
#        409823.86220554, 246175.91297178, 386242.00333052, 577872.56271364,
#        526832.24955511, 400043.61091395, 364680.39071106, 577973.30515915,
#        601520.93514794, 417942.29558896, 470163.06578467, 749533.40914975,
#        445307.11961886, 669842.18699422, 625382.72934421, 519342.81857626,
#        639683.98248004, 499218.39029095, 351485.52154123, 544347.86446842,
#        655449.33093685, 515873.89926878, 728202.68303169, 413304.11011969,
#        470585.30873784, 656826.21419489, 745251.86148797, 556975.74257675,
#        931901.87842926, 792514.89995073, 411692.33191908, 493594.36481678,
#        335813.08110657, 374178.77258964, 546020.59993896, 529968.20959139,
#        656109.65785441, 838628.29523032, 326299.5067098 , 695205.39283892,
#        671119.6377665 , 502477.01422865, 778729.81338853, 535006.84438734,
#        348696.17805797, 544570.17759961, 565571.41947588, 384802.86222048,
#        280006.29093443, 741090.26627192, 627481.0155488 , 526429.40326153,
#        493481.49348155, 280306.39027856, 423405.55353215, 567478.96550114,
#        653324.65471646, 602050.27576056, 378274.53495011, 347305.87897509,
#        709174.47609287, 560178.56793811, 296233.42354117, 348872.2945549 ,
#        743011.93620396, 601253.27850003, 623895.89821532, 728237.54165431,
#        498209.15384427, 447811.77371632, 554364.05171572, 773196.09793109,
#        312483.33067439, 732559.85914097, 395556.27521715, 826506.37413223,
#        566918.14784128, 593917.76391992, 637586.55092401, 715982.25314922,
#        855360.89213115, 538082.67265116, 586020.2378874 , 665000.06654024,
#        540806.1475834 , 621518.79150606, 787431.50445778, 548243.80207662,
#        674670.0370575 , 716578.87326819, 655069.1547437 , 816423.72765398,
#        637171.88169401, 322366.00956743, 530302.31896139, 667119.25403105,
#        481331.8436131 , 575382.36659934, 619988.94675273, 675926.90609892,
#        352497.05264292, 449677.71888091, 717121.23116839, 424988.00112375,
#        609159.07150926, 501150.74262978, 738085.78334749, 528224.54456766,
#        486120.52821761, 764033.99616906, 304082.95672836, 905288.44783575,
#        649980.53969058, 563908.46528861, 495960.38312504, 422037.70353378,
#        737790.04084865, 550105.58743043, 347750.41795859, 503698.17493311,
#        542723.59263081, 945940.11385899, 498453.07026444, 357189.49002412,
#        592338.12476103, 509775.75570321, 373201.66041078, 371578.98377049,
#        326740.72123918, 749493.87028426, 629109.93859852, 611216.40784288,
#        402906.84777712, 616548.12005498, 699256.32772135, 585090.17877275,
#        712474.83833299, 739797.04922942, 702615.54157155, 568439.59778976,
#        490884.41857516, 591123.77457009, 497492.09792603, 700387.3592927 ,
#        479294.43092958, 650053.08154204, 593328.59528647, 562706.69998538,
#        848423.2583604 , 800060.56687274, 635011.32042273, 564107.97014236,
#        914906.14544017, 622538.22382022, 148350.6921241 , 598493.10061474,
#        632725.08947032, 526055.41624394, 460151.85664392, 486024.69737436,
#        717359.63361943, 720810.90889472, 665268.05135884, 743277.72879216,
#        503556.96574848, 645790.38069437, 689740.84435251, 514734.4357903 ,
#        803436.27371128, 740782.43114953, 477416.69114774, 767468.24799652,
#        572343.74934558, 634437.38776309, 769327.49483269, 463182.88106091,
#        839054.70166153, 563730.54069253, 655342.91487069, 464123.6181883 ,
#        791854.43516108, 790152.69598462, 286335.36274459, 674238.32169871,
#        635012.22147301, 408507.7832908 , 479263.94697139, 738325.88601649,
#        532169.53205862, 612283.52567878, 348051.32047508, 645046.50860852,
#        884857.4972212 , 316636.93791775, 456464.12897164, 541664.62836299,
#        973366.99764874, 478527.94281232, 526884.16160783, 666806.11456747,
#        558617.2384774 , 711330.54505659, 726195.75665386, 582739.68769729,
#        562720.95471638, 650366.33509851, 537010.87918794, 506171.80070473,
#        462974.0427551 , 483546.60477423, 712645.3678621 , 255504.89176307,
#        707845.82086753, 468014.43829829, 443477.51373944, 500607.61175467,
#        808486.65992486, 643872.20443678, 627248.99406868, 632956.83093745,
#        828958.59140081, 245960.69013089, 680344.638699  , 672712.06645822,
#        648806.9477968 , 553951.50739796, 722494.31253059, 212561.19499164,
#        497892.64574725, 789861.84613649, 540054.26772901, 883757.87509828,
#        345280.39998546, 507602.73414431, 444401.42359804, 501881.01335286,
#        586664.8864455 , 629377.9129066 , 723622.41609421, 700476.31010526,
#        828988.19312397, 378493.00119052, 422634.36637678])

# %%
y_test
# Out:
# 90     916258.69
# 254    643899.59
# 283    163206.19
# 445    392776.40
# 461    949711.29
#          ...
# 269    248413.93
# 226    767242.37
# 414    415962.40
# 3      611720.42
# 378    491656.98
# Name: loan_amount, Length: 335, dtype: float64

# %%
result = pd.DataFrame()
pd.set_option('display.float_format', '{:.2f}'.format)
result['actual_loan_amount'] = y_test
result['predicted_loan_amount'] = y_pred
result = result.sort_index(axis = 0) 
result
# Out:
#      actual_loan_amount  predicted_loan_amount
# 1             128789.42              439813.51
# 2             177013.90              498453.07
# 3             611720.42              378493.00
# 4             449732.51              280306.39
# 5             109354.09              602050.28
# ..                  ...                    ...
# 494           140399.67              468014.44
# 495           505474.34              883757.88
# 496           245122.49              586020.24
# 497           373220.98              643872.20
# 499           580353.56              566918.15
#
# [335 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(result['actual_loan_amount'][:10], '*')
plt.plot(result['predicted_loan_amount'][:10], 'o')

plt.show()

# %%
print(linreg.score(X_test, y_test))
# Out:
# -0.43884525661068485

# %%
linreg.intercept_
# Out:
# 11883295.224940505

# %% [raw]
# "Hello"
